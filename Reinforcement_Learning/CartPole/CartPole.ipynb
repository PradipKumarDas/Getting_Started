# %% [markdown]
# # **CartPole - The OpenAI Gym CartPole Environment**
#
# _A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The goal is to prevent the pole from falling over._
#
# https://gym.openai.com/envs/CartPole-v1/

# %% [markdown]
# ## Agent's Random Actions (without training) with the Environment

# %%
# Imports required packages

import gym
from gym.wrappers.monitoring.video_recorder import VideoRecorder
from pyvirtualdisplay import Display

import ray
from ray.rllib.agents.ppo import PPOTrainer

# %%
# Creates environment for cartpole
env = gym.make("CartPole-v1")

# %%
# Checks for available actions available in the enviroment
env.action_space
# Out:
# Discrete(2)

# %%
# Instantiate virtual display to record video
display = Display(visible=False, size=(1400, 900))
_ = display.start()

# Sets path of the video file
before_training_video_file = "./before_training.mp4"

# %%
# Creates video recorder instance
video = VideoRecorder(env, before_training_video_file)

# Resets environment
env.reset()

# Start interacting with the environment and records each interactions
for i in range(200):
    env.render()
    video.capture_frame()
    
    observation, reward, done, info = env.step(env.action_space.sample())
    
    #print("step:", i, observation, reward, done, info)
#     if done:
#         print("Episode finished after {} timesteps".format(i+1))
#         break

# Closes video recorder and environment
video.close()
env.close()
# Out:
# /home/pradip/anaconda3/lib/python3.7/site-packages/gym/logger.py:34: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
# Displays the recorded video here in notebook
from IPython.display import HTML
from render_video import render_mp4
html = render_mp4(before_training_video_file)
HTML(html)
# Out:
# <video width=400 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %% [markdown]
# ## Training the Agent

# %%
config = {
    "env": "CartPole-v1",
    "framework": "torch",  # or "tf" for Tensorflow
    "model": {
        "fcnet_hiddens": [32],
        "fcnet_activation": "linear",  # other option is "relu"
    },
}

stop = {"episode_reward_mean": 195}

# %%
ray.shutdown()

ray.init(
    num_cpus=8,  # check number of CPU cores available in your computer
    include_dashboard=False,
    ignore_reinit_error=True,
    log_to_driver=False,
)
# Out:
# {'node_ip_address': '192.168.226.49',
#  'raylet_ip_address': '192.168.226.49',
#  'redis_address': '192.168.226.49:6379',
#  'object_store_address': '/tmp/ray/session_2021-10-09_09-19-10_969877_72352/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-10-09_09-19-10_969877_72352/sockets/raylet',
#  'webui_url': None,
#  'session_dir': '/tmp/ray/session_2021-10-09_09-19-10_969877_72352',
#  'metrics_export_port': 52744,
#  'node_id': '219612646b0e0a46df8a30a0d9a30de1412850b33f2d929527ca939c'}

# %%
# Performs training

analysis = ray.tune.run(
    "PPO",  # Proximal Policy Optimization algorithm
    config=config,
    stop=stop,
    checkpoint_at_end=True,
)
# Out:
# == Status ==<br>Memory usage on this node: 3.5/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 4000
#   custom_metrics: {}
#   date: 2021-10-09_09-19-28
#   done: false
#   episode_len_mean: 21.641304347826086
#   episode_media: {}
#   episode_reward_max: 76.0
#   episode_reward_mean: 21.641304347826086
#   episode_reward_min: 9.0
#   episodes_this_iter: 184
#   episodes_total: 184
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.6841155102816961
#           entropy_coeff: 0.0
#           kl: 0.009076417564353886
#           policy_loss: -0.01536057619478113
#           total_loss: 211.85406045400967
#           vf_explained_var:
#           - -0.0034129756968468428
#           vf_loss: 211.86760523806336
#         model: {}
#     num_agent_steps_sampled: 4000
#     num_agent_steps_trained: 4000
#     num_steps_sampled: 4000
#     num_steps_trained: 4000
#   iterations_since_restore: 1
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.355555555555554
#     ram_util_percent: 61.24444444444444
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05966140148296372
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08660939014183584
#     mean_inference_ms: 1.0823025540868523
#     mean_raw_obs_processing_ms: 0.11518419072538037
#   time_since_restore: 5.8483123779296875
#   time_this_iter_s: 5.8483123779296875
#   time_total_s: 5.8483123779296875
#   timers:
#     learn_throughput: 1312.794
#     learn_time_ms: 3046.936
#     load_throughput: 34030864.097
#     load_time_ms: 0.118
#     sample_throughput: 1433.615
#     sample_time_ms: 2790.15
#     update_time_ms: 1.224
#   timestamp: 1633751368
#   timesteps_since_restore: 0
#   timesteps_total: 4000
#   training_iteration: 1
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">     1</td><td style="text-align: right;">         5.84831</td><td style="text-align: right;">4000</td><td style="text-align: right;"> 21.6413</td><td style="text-align: right;">                  76</td><td style="text-align: right;">                   9</td><td style="text-align: right;">           21.6413</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 8000
#   custom_metrics: {}
#   date: 2021-10-09_09-19-34
#   done: false
#   episode_len_mean: 27.853146853146853
#   episode_media: {}
#   episode_reward_max: 98.0
#   episode_reward_mean: 27.853146853146853
#   episode_reward_min: 10.0
#   episodes_this_iter: 143
#   episodes_total: 327
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.6629990611665992
#           entropy_coeff: 0.0
#           kl: 0.007639680380999725
#           policy_loss: -0.01475261773473473
#           total_loss: 335.232994333903
#           vf_explained_var:
#           - 0.005760434083640575
#           vf_loss: 335.24621771535567
#         model: {}
#     num_agent_steps_sampled: 8000
#     num_agent_steps_trained: 8000
#     num_steps_sampled: 8000
#     num_steps_trained: 8000
#   iterations_since_restore: 2
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 25.51111111111111
#     ram_util_percent: 61.411111111111104
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06004798624491669
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08735537425438886
#     mean_inference_ms: 1.0884393740685172
#     mean_raw_obs_processing_ms: 0.11328425847048657
#   time_since_restore: 11.86736798286438
#   time_this_iter_s: 6.019055604934692
#   time_total_s: 11.86736798286438
#   timers:
#     learn_throughput: 1279.463
#     learn_time_ms: 3126.312
#     load_throughput: 43351979.328
#     load_time_ms: 0.092
#     sample_throughput: 1431.474
#     sample_time_ms: 2794.322
#     update_time_ms: 1.192
#   timestamp: 1633751374
#   timesteps_since_restore: 0
#   timesteps_total: 8000
#   training_iteration: 2
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">     2</td><td style="text-align: right;">         11.8674</td><td style="text-align: right;">8000</td><td style="text-align: right;"> 27.8531</td><td style="text-align: right;">                  98</td><td style="text-align: right;">                  10</td><td style="text-align: right;">           27.8531</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 12000
#   custom_metrics: {}
#   date: 2021-10-09_09-19-40
#   done: false
#   episode_len_mean: 37.61904761904762
#   episode_media: {}
#   episode_reward_max: 121.0
#   episode_reward_mean: 37.61904761904762
#   episode_reward_min: 9.0
#   episodes_this_iter: 105
#   episodes_total: 432
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.6376500448872966
#           entropy_coeff: 0.0
#           kl: 0.00621791095632322
#           policy_loss: -0.013186882926972322
#           total_loss: 494.13562277517013
#           vf_explained_var:
#           - -0.015388996340334415
#           vf_loss: 494.14756729782266
#         model: {}
#     num_agent_steps_sampled: 12000
#     num_agent_steps_trained: 12000
#     num_steps_sampled: 12000
#     num_steps_trained: 12000
#   iterations_since_restore: 3
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 29.087500000000002
#     ram_util_percent: 61.525
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.061149254583508214
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08913929420186832
#     mean_inference_ms: 1.1077339678846443
#     mean_raw_obs_processing_ms: 0.11267355372058331
#   time_since_restore: 18.099525928497314
#   time_this_iter_s: 6.232157945632935
#   time_total_s: 18.099525928497314
#   timers:
#     learn_throughput: 1256.132
#     learn_time_ms: 3184.378
#     load_throughput: 46218225.895
#     load_time_ms: 0.087
#     sample_throughput: 1410.144
#     sample_time_ms: 2836.589
#     update_time_ms: 1.238
#   timestamp: 1633751380
#   timesteps_since_restore: 0
#   timesteps_total: 12000
#   training_iteration: 3
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">     3</td><td style="text-align: right;">         18.0995</td><td style="text-align: right;">12000</td><td style="text-align: right;">  37.619</td><td style="text-align: right;">                 121</td><td style="text-align: right;">                   9</td><td style="text-align: right;">            37.619</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 16000
#   custom_metrics: {}
#   date: 2021-10-09_09-19-46
#   done: false
#   episode_len_mean: 52.32
#   episode_media: {}
#   episode_reward_max: 189.0
#   episode_reward_mean: 52.32
#   episode_reward_min: 12.0
#   episodes_this_iter: 71
#   episodes_total: 503
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.6209945523610679
#           entropy_coeff: 0.0
#           kl: 0.003941223887489885
#           policy_loss: -0.014729969517918684
#           total_loss: 907.894780969107
#           vf_explained_var:
#           - -0.0003590714477468282
#           vf_loss: 907.9087213331653
#         model: {}
#     num_agent_steps_sampled: 16000
#     num_agent_steps_trained: 16000
#     num_steps_sampled: 16000
#     num_steps_trained: 16000
#   iterations_since_restore: 4
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.12222222222222
#     ram_util_percent: 61.44444444444444
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06068123991738801
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08882204498243096
#     mean_inference_ms: 1.0983886677616617
#     mean_raw_obs_processing_ms: 0.11068886696111628
#   time_since_restore: 23.98815369606018
#   time_this_iter_s: 5.888627767562866
#   time_total_s: 23.98815369606018
#   timers:
#     learn_throughput: 1260.66
#     learn_time_ms: 3172.942
#     load_throughput: 42826333.121
#     load_time_ms: 0.093
#     sample_throughput: 1422.059
#     sample_time_ms: 2812.823
#     update_time_ms: 1.223
#   timestamp: 1633751386
#   timesteps_since_restore: 0
#   timesteps_total: 16000
#   training_iteration: 4
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">     4</td><td style="text-align: right;">         23.9882</td><td style="text-align: right;">16000</td><td style="text-align: right;">   52.32</td><td style="text-align: right;">                 189</td><td style="text-align: right;">                  12</td><td style="text-align: right;">             52.32</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 20000
#   custom_metrics: {}
#   date: 2021-10-09_09-19-52
#   done: false
#   episode_len_mean: 71.48
#   episode_media: {}
#   episode_reward_max: 228.0
#   episode_reward_mean: 71.48
#   episode_reward_min: 12.0
#   episodes_this_iter: 42
#   episodes_total: 545
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.10000000000000002
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.6070079863712352
#           entropy_coeff: 0.0
#           kl: 0.0036110141408952036
#           policy_loss: -0.013322689568483701
#           total_loss: 1518.5012674639302
#           vf_explained_var:
#           - -0.007517707068473101
#           vf_loss: 1518.5142368439706
#         model: {}
#     num_agent_steps_sampled: 20000
#     num_agent_steps_trained: 20000
#     num_steps_sampled: 20000
#     num_steps_trained: 20000
#   iterations_since_restore: 5
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.4
#     ram_util_percent: 61.45
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.060559008726750053
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08860693909475875
#     mean_inference_ms: 1.0944011876365796
#     mean_raw_obs_processing_ms: 0.10895150853800491
#   time_since_restore: 29.733017206192017
#   time_this_iter_s: 5.744863510131836
#   time_total_s: 29.733017206192017
#   timers:
#     learn_throughput: 1272.524
#     learn_time_ms: 3143.358
#     load_throughput: 45739411.123
#     load_time_ms: 0.087
#     sample_throughput: 1432.428
#     sample_time_ms: 2792.462
#     update_time_ms: 1.221
#   timestamp: 1633751392
#   timesteps_since_restore: 0
#   timesteps_total: 20000
#   training_iteration: 5
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">     5</td><td style="text-align: right;">          29.733</td><td style="text-align: right;">20000</td><td style="text-align: right;">   71.48</td><td style="text-align: right;">                 228</td><td style="text-align: right;">                  12</td><td style="text-align: right;">             71.48</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 24000
#   custom_metrics: {}
#   date: 2021-10-09_09-19-58
#   done: false
#   episode_len_mean: 91.21
#   episode_media: {}
#   episode_reward_max: 348.0
#   episode_reward_mean: 91.21
#   episode_reward_min: 12.0
#   episodes_this_iter: 28
#   episodes_total: 573
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.05000000000000001
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.5906560885008946
#           entropy_coeff: 0.0
#           kl: 0.0022350361641293513
#           policy_loss: -0.01266468099508715
#           total_loss: 1936.305871188256
#           vf_explained_var:
#           - -0.027071358636021614
#           vf_loss: 1936.3184260542675
#         model: {}
#     num_agent_steps_sampled: 24000
#     num_agent_steps_trained: 24000
#     num_steps_sampled: 24000
#     num_steps_trained: 24000
#   iterations_since_restore: 6
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.211111111111112
#     ram_util_percent: 61.400000000000006
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06044378619784925
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08846292847526342
#     mean_inference_ms: 1.0908979940212848
#     mean_raw_obs_processing_ms: 0.1078130420633547
#   time_since_restore: 35.54263663291931
#   time_this_iter_s: 5.809619426727295
#   time_total_s: 35.54263663291931
#   timers:
#     learn_throughput: 1276.756
#     learn_time_ms: 3132.941
#     load_throughput: 47821043.23
#     load_time_ms: 0.084
#     sample_throughput: 1438.593
#     sample_time_ms: 2780.494
#     update_time_ms: 1.212
#   timestamp: 1633751398
#   timesteps_since_restore: 0
#   timesteps_total: 24000
#   training_iteration: 6
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">     6</td><td style="text-align: right;">         35.5426</td><td style="text-align: right;">24000</td><td style="text-align: right;">   91.21</td><td style="text-align: right;">                 348</td><td style="text-align: right;">                  12</td><td style="text-align: right;">             91.21</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 28000
#   custom_metrics: {}
#   date: 2021-10-09_09-20-04
#   done: false
#   episode_len_mean: 119.79
#   episode_media: {}
#   episode_reward_max: 385.0
#   episode_reward_mean: 119.79
#   episode_reward_min: 15.0
#   episodes_this_iter: 23
#   episodes_total: 596
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.025000000000000005
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.5846601717574622
#           entropy_coeff: 0.0
#           kl: 0.002400839100962113
#           policy_loss: -0.012570964627128135
#           total_loss: 2280.72630234585
#           vf_explained_var:
#           - -0.046364810317754745
#           vf_loss: 2280.7388110089046
#         model: {}
#     num_agent_steps_sampled: 28000
#     num_agent_steps_trained: 28000
#     num_steps_sampled: 28000
#     num_steps_trained: 28000
#   iterations_since_restore: 7
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 27.1125
#     ram_util_percent: 61.475
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06057718229469034
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08848893602941549
#     mean_inference_ms: 1.0913137555416614
#     mean_raw_obs_processing_ms: 0.10662344771001804
#   time_since_restore: 41.52707314491272
#   time_this_iter_s: 5.984436511993408
#   time_total_s: 41.52707314491272
#   timers:
#     learn_throughput: 1275.344
#     learn_time_ms: 3136.408
#     load_throughput: 46733192.201
#     load_time_ms: 0.086
#     sample_throughput: 1435.743
#     sample_time_ms: 2786.014
#     update_time_ms: 1.212
#   timestamp: 1633751404
#   timesteps_since_restore: 0
#   timesteps_total: 28000
#   training_iteration: 7
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">     7</td><td style="text-align: right;">         41.5271</td><td style="text-align: right;">28000</td><td style="text-align: right;">  119.79</td><td style="text-align: right;">                 385</td><td style="text-align: right;">                  15</td><td style="text-align: right;">            119.79</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 32000
#   custom_metrics: {}
#   date: 2021-10-09_09-20-10
#   done: false
#   episode_len_mean: 142.66
#   episode_media: {}
#   episode_reward_max: 385.0
#   episode_reward_mean: 142.66
#   episode_reward_min: 27.0
#   episodes_this_iter: 22
#   episodes_total: 618
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.012500000000000002
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.5930653524014258
#           entropy_coeff: 0.0
#           kl: 0.0011443538453852382
#           policy_loss: -0.00988304220310222
#           total_loss: 2326.873620999244
#           vf_explained_var:
#           - -0.06786046922206879
#           vf_loss: 2326.883485593078
#         model: {}
#     num_agent_steps_sampled: 32000
#     num_agent_steps_trained: 32000
#     num_steps_sampled: 32000
#     num_steps_trained: 32000
#   iterations_since_restore: 8
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.75
#     ram_util_percent: 61.5
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.060526512892441015
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08851747026879343
#     mean_inference_ms: 1.089452914296419
#     mean_raw_obs_processing_ms: 0.10578124095706638
#   time_since_restore: 47.36748027801514
#   time_this_iter_s: 5.840407133102417
#   time_total_s: 47.36748027801514
#   timers:
#     learn_throughput: 1276.372
#     learn_time_ms: 3133.884
#     load_throughput: 46474282.548
#     load_time_ms: 0.086
#     sample_throughput: 1440.225
#     sample_time_ms: 2777.343
#     update_time_ms: 1.203
#   timestamp: 1633751410
#   timesteps_since_restore: 0
#   timesteps_total: 32000
#   training_iteration: 8
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">     8</td><td style="text-align: right;">         47.3675</td><td style="text-align: right;">32000</td><td style="text-align: right;">  142.66</td><td style="text-align: right;">                 385</td><td style="text-align: right;">                  27</td><td style="text-align: right;">            142.66</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 36000
#   custom_metrics: {}
#   date: 2021-10-09_09-20-16
#   done: false
#   episode_len_mean: 164.65
#   episode_media: {}
#   episode_reward_max: 385.0
#   episode_reward_mean: 164.65
#   episode_reward_min: 27.0
#   episodes_this_iter: 21
#   episodes_total: 639
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.006250000000000001
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.5910115479782063
#           entropy_coeff: 0.0
#           kl: 0.0031674888009952003
#           policy_loss: -0.011215650614210836
#           total_loss: 1898.4928074334257
#           vf_explained_var:
#           - -0.018399318680167198
#           vf_loss: 1898.5040001653856
#         model: {}
#     num_agent_steps_sampled: 36000
#     num_agent_steps_trained: 36000
#     num_steps_sampled: 36000
#     num_steps_trained: 36000
#   iterations_since_restore: 9
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.255555555555556
#     ram_util_percent: 61.5
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06066376428221052
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.088575968920249
#     mean_inference_ms: 1.0903241639519834
#     mean_raw_obs_processing_ms: 0.10486586279334403
#   time_since_restore: 53.313053607940674
#   time_this_iter_s: 5.945573329925537
#   time_total_s: 53.313053607940674
#   timers:
#     learn_throughput: 1274.675
#     learn_time_ms: 3138.055
#     load_throughput: 45316609.844
#     load_time_ms: 0.088
#     sample_throughput: 1440.988
#     sample_time_ms: 2775.874
#     update_time_ms: 1.218
#   timestamp: 1633751416
#   timesteps_since_restore: 0
#   timesteps_total: 36000
#   training_iteration: 9
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">     9</td><td style="text-align: right;">         53.3131</td><td style="text-align: right;">36000</td><td style="text-align: right;">  164.65</td><td style="text-align: right;">                 385</td><td style="text-align: right;">                  27</td><td style="text-align: right;">            164.65</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 40000
#   custom_metrics: {}
#   date: 2021-10-09_09-20-22
#   done: false
#   episode_len_mean: 178.79
#   episode_media: {}
#   episode_reward_max: 385.0
#   episode_reward_mean: 178.79
#   episode_reward_min: 33.0
#   episodes_this_iter: 21
#   episodes_total: 660
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.0031250000000000006
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.5934345995226215
#           entropy_coeff: 0.0
#           kl: 0.001961056911218222
#           policy_loss: -0.010255103332981947
#           total_loss: 1979.0496925600114
#           vf_explained_var:
#           - 0.010294581763446331
#           vf_loss: 1979.0599411831108
#         model: {}
#     num_agent_steps_sampled: 40000
#     num_agent_steps_trained: 40000
#     num_steps_sampled: 40000
#     num_steps_trained: 40000
#   iterations_since_restore: 10
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 26.022222222222226
#     ram_util_percent: 61.51111111111111
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.0607295573267741
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08872620648085469
#     mean_inference_ms: 1.0909260334335336
#     mean_raw_obs_processing_ms: 0.10425279608072392
#   time_since_restore: 59.3443808555603
#   time_this_iter_s: 6.031327247619629
#   time_total_s: 59.3443808555603
#   timers:
#     learn_throughput: 1273.173
#     learn_time_ms: 3141.757
#     load_throughput: 44384169.312
#     load_time_ms: 0.09
#     sample_throughput: 1437.295
#     sample_time_ms: 2783.005
#     update_time_ms: 1.206
#   timestamp: 1633751422
#   timesteps_since_restore: 0
#   timesteps_total: 40000
#   training_iteration: 10
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">    10</td><td style="text-align: right;">         59.3444</td><td style="text-align: right;">40000</td><td style="text-align: right;">  178.79</td><td style="text-align: right;">                 385</td><td style="text-align: right;">                  33</td><td style="text-align: right;">            178.79</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 44000
#   custom_metrics: {}
#   date: 2021-10-09_09-20-28
#   done: false
#   episode_len_mean: 183.8
#   episode_media: {}
#   episode_reward_max: 408.0
#   episode_reward_mean: 183.8
#   episode_reward_min: 13.0
#   episodes_this_iter: 20
#   episodes_total: 680
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.0015625000000000003
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.582460597958616
#           entropy_coeff: 0.0
#           kl: 0.0012425415469802588
#           policy_loss: -0.010345979183111139
#           total_loss: 1997.9713784494709
#           vf_explained_var:
#           - 0.01507281418889761
#           vf_loss: 1997.981714982884
#         model: {}
#     num_agent_steps_sampled: 44000
#     num_agent_steps_trained: 44000
#     num_steps_sampled: 44000
#     num_steps_trained: 44000
#   iterations_since_restore: 11
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 27.6875
#     ram_util_percent: 61.5375
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.060860075271262
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08883394794274033
#     mean_inference_ms: 1.0923434662407028
#     mean_raw_obs_processing_ms: 0.1036434479557514
#   time_since_restore: 65.36853122711182
#   time_this_iter_s: 6.024150371551514
#   time_total_s: 65.36853122711182
#   timers:
#     learn_throughput: 1266.801
#     learn_time_ms: 3157.56
#     load_throughput: 45343827.027
#     load_time_ms: 0.088
#     sample_throughput: 1436.225
#     sample_time_ms: 2785.079
#     update_time_ms: 1.194
#   timestamp: 1633751428
#   timesteps_since_restore: 0
#   timesteps_total: 44000
#   training_iteration: 11
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">    11</td><td style="text-align: right;">         65.3685</td><td style="text-align: right;">44000</td><td style="text-align: right;">   183.8</td><td style="text-align: right;">                 408</td><td style="text-align: right;">                  13</td><td style="text-align: right;">             183.8</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v1_df90f_00000:
#   agent_timesteps_total: 48000
#   custom_metrics: {}
#   date: 2021-10-09_09-20-34
#   done: true
#   episode_len_mean: 196.69
#   episode_media: {}
#   episode_reward_max: 408.0
#   episode_reward_mean: 196.69
#   episode_reward_min: 13.0
#   episodes_this_iter: 18
#   episodes_total: 698
#   experiment_id: 835c6130ec3a480fb1cb23e5c4f0294d
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.0007812500000000002
#           cur_lr: 5.0000000000000016e-05
#           entropy: 0.5838937960645204
#           entropy_coeff: 0.0
#           kl: 0.00041761561195637216
#           policy_loss: -0.00932417760242618
#           total_loss: 2000.4769756358157
#           vf_explained_var:
#           - 0.0004732272354885936
#           vf_loss: 2000.4863042359711
#         model: {}
#     num_agent_steps_sampled: 48000
#     num_agent_steps_trained: 48000
#     num_steps_sampled: 48000
#     num_steps_trained: 48000
#   iterations_since_restore: 12
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.366666666666664
#     ram_util_percent: 61.51111111111111
#   pid: 103619
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06091131617687207
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08888187503701354
#     mean_inference_ms: 1.0926425970614249
#     mean_raw_obs_processing_ms: 0.1031552683323341
#   time_since_restore: 71.29453778266907
#   time_this_iter_s: 5.926006555557251
#   time_total_s: 71.29453778266907
#   timers:
#     learn_throughput: 1268.25
#     learn_time_ms: 3153.952
#     load_throughput: 40790702.65
#     load_time_ms: 0.098
#     sample_throughput: 1438.822
#     sample_time_ms: 2780.053
#     update_time_ms: 1.183
#   timestamp: 1633751434
#   timesteps_since_restore: 0
#   timesteps_total: 48000
#   training_iteration: 12
#   trial_id: df90f_00000
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>RUNNING </td><td>192.168.226.49:103619</td><td style="text-align: right;">    12</td><td style="text-align: right;">         71.2945</td><td style="text-align: right;">48000</td><td style="text-align: right;">  196.69</td><td style="text-align: right;">                 408</td><td style="text-align: right;">                  13</td><td style="text-align: right;">            196.69</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 4.1/6.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.22 GiB objects<br>Result logdir: /home/pradip/ray_results/PPO<br>Number of trials: 1/1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status    </th><th>loc  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_df90f_00000</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    12</td><td style="text-align: right;">         71.2945</td><td style="text-align: right;">48000</td><td style="text-align: right;">  196.69</td><td style="text-align: right;">                 408</td><td style="text-align: right;">                  13</td><td style="text-align: right;">            196.69</td></tr>
# </tbody>
# </table><br><br>
# 2021-10-09 09:20:34,931	INFO tune.py:561 -- Total run time: 79.43 seconds (78.76 seconds for the tuning loop).

# %% [markdown]
# ## Creating Video of the Trained Model in Action

# %% [markdown]
# **Getting reference to trainer instance**

# %%
trial = analysis.get_best_logdir("episode_reward_mean", "max")
checkpoint = analysis.get_best_checkpoint(trial, "training_iteration", "max")
trainer = PPOTrainer(config=config)
trainer.restore(checkpoint)
# Out:
# 2021-10-09 09:24:01,765	INFO ppo.py:159 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# 2021-10-09 09:24:01,766	INFO trainer.py:728 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2021-10-09 09:24:05,116	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# 2021-10-09 09:24:05,131	INFO trainable.py:383 -- Restored on 192.168.226.49 from checkpoint: /home/pradip/ray_results/PPO/PPO_CartPole-v1_df90f_00000_0_2021-10-09_09-19-15/checkpoint_000012/checkpoint-12
# 2021-10-09 09:24:05,132	INFO trainable.py:390 -- Current state after restoring: {'_iteration': 12, '_timesteps_total': None, '_time_total': 71.29453778266907, '_episodes_total': 698}

# %% [markdown]
# **Creating video**

# %%
after_training_video_file = "after_training.mp4"
after_video = VideoRecorder(env, after_training_video_file)
observation = env.reset()
done = False
while not done:
    env.render()
    after_video.capture_frame()
    action = trainer.compute_single_action(observation)
    observation, reward, done, info = env.step(action)
after_video.close()
env.close()

# %%
# Displays the recorded video here in notebook
from IPython.display import HTML
from render_video import render_mp4
html = render_mp4(after_training_video_file)
HTML(html)
# Out:
# <video width=400 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %% [markdown]
# ## Tuning Hyperparameters

# %%
parameters_search_config = {
    "env": "CartPole-v1",
    "framework": "torch",
    
    # hyperparameters tuning specific - the search space
    
    "model": {
        "fcnet_hiddens": ray.tune.grid_search([[32], [64]]),
        "fcnet_activation": ray.tune.grid_search(["linear", "relu"]),
    },
    "lr": ray.tune.uniform(1e-7, 1e-2)
}

# %%
ray.shutdown()

ray.init(
    num_cpus=8,
    include_dashboard=False,
    ignore_reinit_error=True,
    log_to_driver=False,
)
# Out:
# {'node_ip_address': '192.168.226.49',
#  'raylet_ip_address': '192.168.226.49',
#  'redis_address': '192.168.226.49:6379',
#  'object_store_address': '/tmp/ray/session_2021-10-09_09-43-05_458820_72352/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-10-09_09-43-05_458820_72352/sockets/raylet',
#  'webui_url': None,
#  'session_dir': '/tmp/ray/session_2021-10-09_09-43-05_458820_72352',
#  'metrics_export_port': 46476,
#  'node_id': '726b2a0c5ea256625c83d95460618ad220e4fdce73f9d11e4639d7d6'}

# %%
# Performs hyperparameters tuning

parameters_search_analysis = ray.tune.run(
    "PPO",
    config=parameters_search_config,
    stop=stop,
    num_samples=5,
    metric="timesteps_total",
    mode="min",
)
# Out:
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 4000
#   custom_metrics: {}
#   date: 2021-10-09_09-49-31
#   done: false
#   episode_len_mean: 23.867469879518072
#   episode_media: {}
#   episode_reward_max: 75.0
#   episode_reward_mean: 23.867469879518072
#   episode_reward_min: 8.0
#   episodes_this_iter: 166
#   episodes_total: 166
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004289619884961042
#           entropy: 0.6787872771422069
#           entropy_coeff: 0.0
#           kl: 0.015464462661396247
#           policy_loss: -0.025395593806219998
#           total_loss: 127.63090472272647
#           vf_explained_var:
#           - -0.0024547111243009567
#           vf_loss: 127.65320838394986
#         model: {}
#     num_agent_steps_sampled: 4000
#     num_agent_steps_trained: 4000
#     num_steps_sampled: 4000
#     num_steps_trained: 4000
#   iterations_since_restore: 1
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 40.027272727272724
#     ram_util_percent: 71.36363636363636
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07411188337484385
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10328870995548307
#     mean_inference_ms: 1.4015472096842103
#     mean_raw_obs_processing_ms: 0.13741276332421828
#   time_since_restore: 7.216978073120117
#   time_this_iter_s: 7.216978073120117
#   time_total_s: 7.216978073120117
#   timers:
#     learn_throughput: 1128.438
#     learn_time_ms: 3544.722
#     load_throughput: 57260122.867
#     load_time_ms: 0.07
#     sample_throughput: 1092.506
#     sample_time_ms: 3661.307
#     update_time_ms: 1.483
#   timestamp: 1633753171
#   timesteps_since_restore: 0
#   timesteps_total: 4000
#   training_iteration: 1
#   trial_id: 10bb4_00000
#
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 4000
#   custom_metrics: {}
#   date: 2021-10-09_09-49-31
#   done: false
#   episode_len_mean: 22.127777777777776
#   episode_media: {}
#   episode_reward_max: 65.0
#   episode_reward_mean: 22.127777777777776
#   episode_reward_min: 9.0
#   episodes_this_iter: 180
#   episodes_total: 180
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.009351202585093159
#           entropy: 0.6666804857151483
#           entropy_coeff: 0.0
#           kl: 0.026985852250713566
#           policy_loss: -0.04316047105527613
#           total_loss: 77.26153761956
#           vf_explained_var:
#           - -0.019482258707284927
#           vf_loss: 77.29930071061658
#         model: {}
#     num_agent_steps_sampled: 4000
#     num_agent_steps_trained: 4000
#     num_steps_sampled: 4000
#     num_steps_trained: 4000
#   iterations_since_restore: 1
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 40.00909090909091
#     ram_util_percent: 71.36363636363636
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07535357604756787
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10388017700278347
#     mean_inference_ms: 1.4523219007118942
#     mean_raw_obs_processing_ms: 0.13950736090161095
#   time_since_restore: 7.62404203414917
#   time_this_iter_s: 7.62404203414917
#   time_total_s: 7.62404203414917
#   timers:
#     learn_throughput: 1107.075
#     learn_time_ms: 3613.126
#     load_throughput: 39383136.15
#     load_time_ms: 0.102
#     sample_throughput: 1001.214
#     sample_time_ms: 3995.15
#     update_time_ms: 1.45
#   timestamp: 1633753171
#   timesteps_since_restore: 0
#   timesteps_total: 4000
#   training_iteration: 1
#   trial_id: 10bb4_00001
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 8000
#   custom_metrics: {}
#   date: 2021-10-09_09-49-38
#   done: false
#   episode_len_mean: 34.23076923076923
#   episode_media: {}
#   episode_reward_max: 124.0
#   episode_reward_mean: 34.23076923076923
#   episode_reward_min: 9.0
#   episodes_this_iter: 117
#   episodes_total: 283
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004289619884961042
#           entropy: 0.6449224256059175
#           entropy_coeff: 0.0
#           kl: 0.013650506711322277
#           policy_loss: -0.02403037916187958
#           total_loss: 201.05899459264612
#           vf_explained_var:
#           - 0.00172094302251935
#           vf_loss: 201.08029574732626
#         model: {}
#     num_agent_steps_sampled: 8000
#     num_agent_steps_trained: 8000
#     num_steps_sampled: 8000
#     num_steps_trained: 8000
#   iterations_since_restore: 2
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 46.18
#     ram_util_percent: 71.5
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07378975952182468
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10355498041606168
#     mean_inference_ms: 1.390482747880765
#     mean_raw_obs_processing_ms: 0.13368566981455268
#   time_since_restore: 14.456310749053955
#   time_this_iter_s: 7.239332675933838
#   time_total_s: 14.456310749053955
#   timers:
#     learn_throughput: 1102.793
#     learn_time_ms: 3627.155
#     load_throughput: 43129089.974
#     load_time_ms: 0.093
#     sample_throughput: 1114.509
#     sample_time_ms: 3589.026
#     update_time_ms: 1.709
#   timestamp: 1633753178
#   timesteps_since_restore: 0
#   timesteps_total: 8000
#   training_iteration: 2
#   trial_id: 10bb4_00000
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 8000
#   custom_metrics: {}
#   date: 2021-10-09_09-49-39
#   done: false
#   episode_len_mean: 40.54
#   episode_media: {}
#   episode_reward_max: 134.0
#   episode_reward_mean: 40.54
#   episode_reward_min: 11.0
#   episodes_this_iter: 96
#   episodes_total: 276
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.009351202585093159
#           entropy: 0.6134269172786384
#           entropy_coeff: 0.0
#           kl: 0.021113158070294718
#           policy_loss: -0.03553879878994438
#           total_loss: 241.45581384474232
#           vf_explained_var:
#           - -0.0007234688964672387
#           vf_loss: 241.48501852712323
#         model: {}
#     num_agent_steps_sampled: 8000
#     num_agent_steps_trained: 8000
#     num_steps_sampled: 8000
#     num_steps_trained: 8000
#   iterations_since_restore: 2
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 45.163636363636364
#     ram_util_percent: 71.52727272727273
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.0750686315625761
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10419477975357833
#     mean_inference_ms: 1.4425390917598064
#     mean_raw_obs_processing_ms: 0.1338814357811458
#   time_since_restore: 15.106293678283691
#   time_this_iter_s: 7.4822516441345215
#   time_total_s: 15.106293678283691
#   timers:
#     learn_throughput: 1071.995
#     learn_time_ms: 3731.361
#     load_throughput: 38612695.052
#     load_time_ms: 0.104
#     sample_throughput: 1050.398
#     sample_time_ms: 3808.079
#     update_time_ms: 1.447
#   timestamp: 1633753179
#   timesteps_since_restore: 0
#   timesteps_total: 8000
#   training_iteration: 2
#   trial_id: 10bb4_00001
#
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 12000
#   custom_metrics: {}
#   date: 2021-10-09_09-49-45
#   done: false
#   episode_len_mean: 52.12
#   episode_media: {}
#   episode_reward_max: 189.0
#   episode_reward_mean: 52.12
#   episode_reward_min: 9.0
#   episodes_this_iter: 59
#   episodes_total: 342
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004289619884961042
#           entropy: 0.6129483734407732
#           entropy_coeff: 0.0
#           kl: 0.009466977680577391
#           policy_loss: -0.015091216182636638
#           total_loss: 402.2826273354151
#           vf_explained_var:
#           - 0.017069533467292786
#           vf_loss: 402.29582458003875
#         model: {}
#     num_agent_steps_sampled: 12000
#     num_agent_steps_trained: 12000
#     num_steps_sampled: 12000
#     num_steps_trained: 12000
#   iterations_since_restore: 3
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 44.040000000000006
#     ram_util_percent: 71.5
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07415127173791797
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.1042168006362051
#     mean_inference_ms: 1.3938329345357858
#     mean_raw_obs_processing_ms: 0.131409681208159
#   time_since_restore: 21.50757670402527
#   time_this_iter_s: 7.0512659549713135
#   time_total_s: 21.50757670402527
#   timers:
#     learn_throughput: 1121.592
#     learn_time_ms: 3566.359
#     load_throughput: 41087059.592
#     load_time_ms: 0.097
#     sample_throughput: 1113.704
#     sample_time_ms: 3591.619
#     update_time_ms: 1.595
#   timestamp: 1633753185
#   timesteps_since_restore: 0
#   timesteps_total: 12000
#   training_iteration: 3
#   trial_id: 10bb4_00000
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 12000
#   custom_metrics: {}
#   date: 2021-10-09_09-49-46
#   done: false
#   episode_len_mean: 59.83
#   episode_media: {}
#   episode_reward_max: 206.0
#   episode_reward_mean: 59.83
#   episode_reward_min: 13.0
#   episodes_this_iter: 51
#   episodes_total: 327
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.4500000000000001
#           cur_lr: 0.009351202585093159
#           entropy: 0.6017901349452234
#           entropy_coeff: 0.0
#           kl: 0.01356999476778844
#           policy_loss: -0.025687812870588675
#           total_loss: 453.0229283158497
#           vf_explained_var:
#           - 0.004001358989626169
#           vf_loss: 453.042510051112
#         model: {}
#     num_agent_steps_sampled: 12000
#     num_agent_steps_trained: 12000
#     num_steps_sampled: 12000
#     num_steps_trained: 12000
#   iterations_since_restore: 3
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 43.55
#     ram_util_percent: 71.5
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07433544991051666
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10350416590463482
#     mean_inference_ms: 1.4332959905334122
#     mean_raw_obs_processing_ms: 0.13057417877126765
#   time_since_restore: 22.294631242752075
#   time_this_iter_s: 7.188337564468384
#   time_total_s: 22.294631242752075
#   timers:
#     learn_throughput: 1080.596
#     learn_time_ms: 3701.66
#     load_throughput: 38362536.585
#     load_time_ms: 0.104
#     sample_throughput: 1076.067
#     sample_time_ms: 3717.24
#     update_time_ms: 1.711
#   timestamp: 1633753186
#   timesteps_since_restore: 0
#   timesteps_total: 12000
#   training_iteration: 3
#   trial_id: 10bb4_00001
#
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 16000
#   custom_metrics: {}
#   date: 2021-10-09_09-49-52
#   done: false
#   episode_len_mean: 79.93
#   episode_media: {}
#   episode_reward_max: 287.0
#   episode_reward_mean: 79.93
#   episode_reward_min: 11.0
#   episodes_this_iter: 39
#   episodes_total: 381
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004289619884961042
#           entropy: 0.5928243893449024
#           entropy_coeff: 0.0
#           kl: 0.007185755310997056
#           policy_loss: -0.020283234025281604
#           total_loss: 495.89053222492174
#           vf_explained_var:
#           - 0.05921325087547302
#           vf_loss: 495.9093770755235
#         model: {}
#     num_agent_steps_sampled: 16000
#     num_agent_steps_trained: 16000
#     num_steps_sampled: 16000
#     num_steps_trained: 16000
#   iterations_since_restore: 4
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 42.60909090909091
#     ram_util_percent: 71.52727272727272
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07465345492266391
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.1048380956038452
#     mean_inference_ms: 1.4013585851342534
#     mean_raw_obs_processing_ms: 0.13038664789853055
#   time_since_restore: 28.681087970733643
#   time_this_iter_s: 7.173511266708374
#   time_total_s: 28.681087970733643
#   timers:
#     learn_throughput: 1111.945
#     learn_time_ms: 3597.301
#     load_throughput: 42853680.715
#     load_time_ms: 0.093
#     sample_throughput: 1122.794
#     sample_time_ms: 3562.541
#     update_time_ms: 1.529
#   timestamp: 1633753192
#   timesteps_since_restore: 0
#   timesteps_total: 16000
#   training_iteration: 4
#   trial_id: 10bb4_00000
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 16000
#   custom_metrics: {}
#   date: 2021-10-09_09-49-53
#   done: false
#   episode_len_mean: 84.88
#   episode_media: {}
#   episode_reward_max: 228.0
#   episode_reward_mean: 84.88
#   episode_reward_min: 13.0
#   episodes_this_iter: 34
#   episodes_total: 361
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.4500000000000001
#           cur_lr: 0.009351202585093159
#           entropy: 0.5898180996218035
#           entropy_coeff: 0.0
#           kl: 0.007962861504433375
#           policy_loss: -0.018386986122656893
#           total_loss: 405.1331552977203
#           vf_explained_var:
#           - -0.0017129306215792894
#           vf_loss: 405.1479572255124
#         model: {}
#     num_agent_steps_sampled: 16000
#     num_agent_steps_trained: 16000
#     num_steps_sampled: 16000
#     num_steps_trained: 16000
#   iterations_since_restore: 4
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 43.4909090909091
#     ram_util_percent: 71.53636363636363
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07468040855142175
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10398240335703016
#     mean_inference_ms: 1.430800211304977
#     mean_raw_obs_processing_ms: 0.1286657340731974
#   time_since_restore: 29.607483386993408
#   time_this_iter_s: 7.312852144241333
#   time_total_s: 29.607483386993408
#   timers:
#     learn_throughput: 1081.027
#     learn_time_ms: 3700.183
#     load_throughput: 38994110.401
#     load_time_ms: 0.103
#     sample_throughput: 1084.047
#     sample_time_ms: 3689.878
#     update_time_ms: 1.645
#   timestamp: 1633753193
#   timesteps_since_restore: 0
#   timesteps_total: 16000
#   training_iteration: 4
#   trial_id: 10bb4_00001
#
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 20000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-00
#   done: false
#   episode_len_mean: 97.94
#   episode_media: {}
#   episode_reward_max: 287.0
#   episode_reward_mean: 97.94
#   episode_reward_min: 12.0
#   episodes_this_iter: 25
#   episodes_total: 406
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004289619884961042
#           entropy: 0.5867498545236485
#           entropy_coeff: 0.0
#           kl: 0.005754617588682558
#           policy_loss: -0.005172019717233476
#           total_loss: 477.72109744164254
#           vf_explained_var:
#           - 0.016451872885227203
#           vf_loss: 477.7251201670657
#         model: {}
#     num_agent_steps_sampled: 20000
#     num_agent_steps_trained: 20000
#     num_steps_sampled: 20000
#     num_steps_trained: 20000
#   iterations_since_restore: 5
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 43.57
#     ram_util_percent: 71.55
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.0744190438343414
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10462590891558576
#     mean_inference_ms: 1.3939147439309645
#     mean_raw_obs_processing_ms: 0.12840896017096742
#   time_since_restore: 35.874135971069336
#   time_this_iter_s: 7.193048000335693
#   time_total_s: 35.874135971069336
#   timers:
#     learn_throughput: 1092.671
#     learn_time_ms: 3660.755
#     load_throughput: 45245997.843
#     load_time_ms: 0.088
#     sample_throughput: 1141.54
#     sample_time_ms: 3504.039
#     update_time_ms: 1.486
#   timestamp: 1633753200
#   timesteps_since_restore: 0
#   timesteps_total: 20000
#   training_iteration: 5
#   trial_id: 10bb4_00000
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 20000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-01
#   done: false
#   episode_len_mean: 110.88
#   episode_media: {}
#   episode_reward_max: 309.0
#   episode_reward_mean: 110.88
#   episode_reward_min: 16.0
#   episodes_this_iter: 25
#   episodes_total: 386
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.4500000000000001
#           cur_lr: 0.009351202585093159
#           entropy: 0.5970870349355923
#           entropy_coeff: 0.0
#           kl: 0.009138077533796732
#           policy_loss: -0.011465697447138448
#           total_loss: 512.164974319294
#           vf_explained_var:
#           - 0.0725654661655426
#           vf_loss: 512.1723291212512
#         model: {}
#     num_agent_steps_sampled: 20000
#     num_agent_steps_trained: 20000
#     num_steps_sampled: 20000
#     num_steps_trained: 20000
#   iterations_since_restore: 5
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 42.82727272727272
#     ram_util_percent: 71.55454545454546
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07484793005862624
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10424018623429547
#     mean_inference_ms: 1.430144916172453
#     mean_raw_obs_processing_ms: 0.1271126748234931
#   time_since_restore: 37.06546473503113
#   time_this_iter_s: 7.45798134803772
#   time_total_s: 37.06546473503113
#   timers:
#     learn_throughput: 1073.024
#     learn_time_ms: 3727.782
#     load_throughput: 38497512.62
#     load_time_ms: 0.104
#     sample_throughput: 1088.737
#     sample_time_ms: 3673.983
#     update_time_ms: 1.608
#   timestamp: 1633753201
#   timesteps_since_restore: 0
#   timesteps_total: 20000
#   training_iteration: 5
#   trial_id: 10bb4_00001
#
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 24000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-07
#   done: false
#   episode_len_mean: 130.75
#   episode_media: {}
#   episode_reward_max: 453.0
#   episode_reward_mean: 130.75
#   episode_reward_min: 12.0
#   episodes_this_iter: 22
#   episodes_total: 428
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004289619884961042
#           entropy: 0.5800837664834915
#           entropy_coeff: 0.0
#           kl: 0.003726807221841598
#           policy_loss: -0.012475803167989819
#           total_loss: 544.1299942836966
#           vf_explained_var:
#           - 0.051904745399951935
#           vf_loss: 544.1417251258769
#         model: {}
#     num_agent_steps_sampled: 24000
#     num_agent_steps_trained: 24000
#     num_steps_sampled: 24000
#     num_steps_trained: 24000
#   iterations_since_restore: 6
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.489999999999995
#     ram_util_percent: 71.51
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07416095163474803
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10431060706384031
#     mean_inference_ms: 1.386197242231928
#     mean_raw_obs_processing_ms: 0.12668865512955219
#   time_since_restore: 42.74387288093567
#   time_this_iter_s: 6.869736909866333
#   time_total_s: 42.74387288093567
#   timers:
#     learn_throughput: 1099.006
#     learn_time_ms: 3639.653
#     load_throughput: 40443268.783
#     load_time_ms: 0.099
#     sample_throughput: 1151.278
#     sample_time_ms: 3474.399
#     update_time_ms: 1.469
#   timestamp: 1633753207
#   timesteps_since_restore: 0
#   timesteps_total: 24000
#   training_iteration: 6
#   trial_id: 10bb4_00000
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 24000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-08
#   done: false
#   episode_len_mean: 132.39
#   episode_media: {}
#   episode_reward_max: 309.0
#   episode_reward_mean: 132.39
#   episode_reward_min: 17.0
#   episodes_this_iter: 23
#   episodes_total: 409
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.4500000000000001
#           cur_lr: 0.009351202585093159
#           entropy: 0.5887884516869822
#           entropy_coeff: 0.0
#           kl: 0.006668997029084964
#           policy_loss: -0.007464200236223718
#           total_loss: 490.99987538655597
#           vf_explained_var:
#           - 0.1348106563091278
#           vf_loss: 491.00433949296195
#         model: {}
#     num_agent_steps_sampled: 24000
#     num_agent_steps_trained: 24000
#     num_steps_sampled: 24000
#     num_steps_trained: 24000
#   iterations_since_restore: 6
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.82
#     ram_util_percent: 71.5
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07478078455032289
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10419975686923816
#     mean_inference_ms: 1.426789331879067
#     mean_raw_obs_processing_ms: 0.1255892142825209
#   time_since_restore: 43.996037006378174
#   time_this_iter_s: 6.930572271347046
#   time_total_s: 43.996037006378174
#   timers:
#     learn_throughput: 1078.837
#     learn_time_ms: 3707.695
#     load_throughput: 38776308.166
#     load_time_ms: 0.103
#     sample_throughput: 1106.848
#     sample_time_ms: 3613.865
#     update_time_ms: 1.581
#   timestamp: 1633753208
#   timesteps_since_restore: 0
#   timesteps_total: 24000
#   training_iteration: 6
#   trial_id: 10bb4_00001
#
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 28000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-13
#   done: false
#   episode_len_mean: 149.25
#   episode_media: {}
#   episode_reward_max: 453.0
#   episode_reward_mean: 149.25
#   episode_reward_min: 17.0
#   episodes_this_iter: 22
#   episodes_total: 450
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.10000000000000002
#           cur_lr: 0.004289619884961042
#           entropy: 0.6052527237963933
#           entropy_coeff: 0.0
#           kl: 0.005566465612234816
#           policy_loss: -0.002036834524203372
#           total_loss: 443.7741424929711
#           vf_explained_var:
#           - 0.29106569290161133
#           vf_loss: 443.7756206266342
#         model: {}
#     num_agent_steps_sampled: 28000
#     num_agent_steps_trained: 28000
#     num_steps_sampled: 28000
#     num_steps_trained: 28000
#   iterations_since_restore: 7
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.52
#     ram_util_percent: 71.5
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07385770309867627
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.1039132020452968
#     mean_inference_ms: 1.3773239290027561
#     mean_raw_obs_processing_ms: 0.12487028793894836
#   time_since_restore: 49.59491944313049
#   time_this_iter_s: 6.851046562194824
#   time_total_s: 49.59491944313049
#   timers:
#     learn_throughput: 1104.872
#     learn_time_ms: 3620.329
#     load_throughput: 41749204.408
#     load_time_ms: 0.096
#     sample_throughput: 1157.805
#     sample_time_ms: 3454.813
#     update_time_ms: 1.465
#   timestamp: 1633753213
#   timesteps_since_restore: 0
#   timesteps_total: 28000
#   training_iteration: 7
#   trial_id: 10bb4_00000
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 28000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-15
#   done: false
#   episode_len_mean: 152.61
#   episode_media: {}
#   episode_reward_max: 383.0
#   episode_reward_mean: 152.61
#   episode_reward_min: 17.0
#   episodes_this_iter: 23
#   episodes_total: 432
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.4500000000000001
#           cur_lr: 0.009351202585093159
#           entropy: 0.577173468758983
#           entropy_coeff: 0.0
#           kl: 0.008868518336087195
#           policy_loss: -0.008389153940382824
#           total_loss: 395.8680826822917
#           vf_explained_var:
#           - 0.33819279074668884
#           vf_loss: 395.872480814944
#         model: {}
#     num_agent_steps_sampled: 28000
#     num_agent_steps_trained: 28000
#     num_steps_sampled: 28000
#     num_steps_trained: 28000
#   iterations_since_restore: 7
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.72
#     ram_util_percent: 71.5
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07472041231005537
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10417684833073297
#     mean_inference_ms: 1.4205486878531033
#     mean_raw_obs_processing_ms: 0.12391031676414554
#   time_since_restore: 51.028401136398315
#   time_this_iter_s: 7.032364130020142
#   time_total_s: 51.028401136398315
#   timers:
#     learn_throughput: 1080.045
#     learn_time_ms: 3703.55
#     load_throughput: 39238393.585
#     load_time_ms: 0.102
#     sample_throughput: 1118.721
#     sample_time_ms: 3575.512
#     update_time_ms: 1.578
#   timestamp: 1633753215
#   timesteps_since_restore: 0
#   timesteps_total: 28000
#   training_iteration: 7
#   trial_id: 10bb4_00001
#
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 32000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-20
#   done: false
#   episode_len_mean: 170.18
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 170.18
#   episode_reward_min: 17.0
#   episodes_this_iter: 17
#   episodes_total: 467
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.10000000000000002
#           cur_lr: 0.004289619884961042
#           entropy: 0.5737714311128022
#           entropy_coeff: 0.0
#           kl: 0.006919506684022677
#           policy_loss: -0.005251767019671137
#           total_loss: 443.1822440075618
#           vf_explained_var:
#           - 0.3629966676235199
#           vf_loss: 443.1868042197279
#         model: {}
#     num_agent_steps_sampled: 32000
#     num_agent_steps_trained: 32000
#     num_steps_sampled: 32000
#     num_steps_trained: 32000
#   iterations_since_restore: 8
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 40.922222222222224
#     ram_util_percent: 71.5
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07348070714849553
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10345406611653121
#     mean_inference_ms: 1.3676491521153258
#     mean_raw_obs_processing_ms: 0.12326300454162364
#   time_since_restore: 56.26163125038147
#   time_this_iter_s: 6.666711807250977
#   time_total_s: 56.26163125038147
#   timers:
#     learn_throughput: 1108.387
#     learn_time_ms: 3608.848
#     load_throughput: 43073725.289
#     load_time_ms: 0.093
#     sample_throughput: 1171.621
#     sample_time_ms: 3414.074
#     update_time_ms: 1.462
#   timestamp: 1633753220
#   timesteps_since_restore: 0
#   timesteps_total: 32000
#   training_iteration: 8
#   trial_id: 10bb4_00000
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 32000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-22
#   done: false
#   episode_len_mean: 166.55
#   episode_media: {}
#   episode_reward_max: 383.0
#   episode_reward_mean: 166.55
#   episode_reward_min: 24.0
#   episodes_this_iter: 22
#   episodes_total: 454
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.4500000000000001
#           cur_lr: 0.009351202585093159
#           entropy: 0.5674381337819561
#           entropy_coeff: 0.0
#           kl: 0.008619469612049846
#           policy_loss: -0.01507171037336511
#           total_loss: 627.6605570065078
#           vf_explained_var:
#           - 0.038902051746845245
#           vf_loss: 627.6717537951725
#         model: {}
#     num_agent_steps_sampled: 32000
#     num_agent_steps_trained: 32000
#     num_steps_sampled: 32000
#     num_steps_trained: 32000
#   iterations_since_restore: 8
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 40.14
#     ram_util_percent: 71.5
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07438276706344456
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.1038109348599931
#     mean_inference_ms: 1.4110405613380905
#     mean_raw_obs_processing_ms: 0.12229782750052026
#   time_since_restore: 58.02613925933838
#   time_this_iter_s: 6.9977381229400635
#   time_total_s: 58.02613925933838
#   timers:
#     learn_throughput: 1077.964
#     learn_time_ms: 3710.7
#     load_throughput: 37701608.989
#     load_time_ms: 0.106
#     sample_throughput: 1132.522
#     sample_time_ms: 3531.941
#     update_time_ms: 1.561
#   timestamp: 1633753222
#   timesteps_since_restore: 0
#   timesteps_total: 32000
#   training_iteration: 8
#   trial_id: 10bb4_00001
#
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 36000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-27
#   done: false
#   episode_len_mean: 192.69
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 192.69
#   episode_reward_min: 34.0
#   episodes_this_iter: 18
#   episodes_total: 485
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.10000000000000002
#           cur_lr: 0.004289619884961042
#           entropy: 0.6021566764000923
#           entropy_coeff: 0.0
#           kl: 0.006993134774739494
#           policy_loss: -0.002088348986080257
#           total_loss: 697.0666947928808
#           vf_explained_var:
#           - 0.057107724249362946
#           vf_loss: 697.0680833262782
#         model: {}
#     num_agent_steps_sampled: 36000
#     num_agent_steps_trained: 36000
#     num_steps_sampled: 36000
#     num_steps_trained: 36000
#   iterations_since_restore: 9
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.31
#     ram_util_percent: 71.52000000000001
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07308421133415774
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10295919289004644
#     mean_inference_ms: 1.3573568017883957
#     mean_raw_obs_processing_ms: 0.1217149394139365
#   time_since_restore: 63.14165163040161
#   time_this_iter_s: 6.880020380020142
#   time_total_s: 63.14165163040161
#   timers:
#     learn_throughput: 1107.109
#     learn_time_ms: 3613.012
#     load_throughput: 41266724.242
#     load_time_ms: 0.097
#     sample_throughput: 1178.866
#     sample_time_ms: 3393.092
#     update_time_ms: 1.449
#   timestamp: 1633753227
#   timesteps_since_restore: 0
#   timesteps_total: 36000
#   training_iteration: 9
#   trial_id: 10bb4_00000
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 36000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-29
#   done: false
#   episode_len_mean: 182.87
#   episode_media: {}
#   episode_reward_max: 412.0
#   episode_reward_mean: 182.87
#   episode_reward_min: 24.0
#   episodes_this_iter: 17
#   episodes_total: 471
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.4500000000000001
#           cur_lr: 0.009351202585093159
#           entropy: 0.5783461945672189
#           entropy_coeff: 0.0
#           kl: 0.006866376416953085
#           policy_loss: -0.008296673037912898
#           total_loss: 599.8750567528509
#           vf_explained_var:
#           - 0.011068561114370823
#           vf_loss: 599.8802652953773
#         model: {}
#     num_agent_steps_sampled: 36000
#     num_agent_steps_trained: 36000
#     num_steps_sampled: 36000
#     num_steps_trained: 36000
#   iterations_since_restore: 9
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.33
#     ram_util_percent: 71.52000000000001
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07402097506513323
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10339660833445766
#     mean_inference_ms: 1.4022481255249182
#     mean_raw_obs_processing_ms: 0.12097840182125345
#   time_since_restore: 64.99877262115479
#   time_this_iter_s: 6.972633361816406
#   time_total_s: 64.99877262115479
#   timers:
#     learn_throughput: 1078.36
#     learn_time_ms: 3709.336
#     load_throughput: 38896173.107
#     load_time_ms: 0.103
#     sample_throughput: 1142.117
#     sample_time_ms: 3502.268
#     update_time_ms: 1.53
#   timestamp: 1633753229
#   timesteps_since_restore: 0
#   timesteps_total: 36000
#   training_iteration: 9
#   trial_id: 10bb4_00001
#
# Result for PPO_CartPole-v1_10bb4_00000:
#   agent_timesteps_total: 40000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-34
#   done: true
#   episode_len_mean: 208.88
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 208.88
#   episode_reward_min: 52.0
#   episodes_this_iter: 16
#   episodes_total: 501
#   experiment_id: 254202ce3b2741abbe62e47f0c11a341
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.10000000000000002
#           cur_lr: 0.004289619884961042
#           entropy: 0.5815486903472613
#           entropy_coeff: 0.0
#           kl: 0.003639774427268617
#           policy_loss: 0.002122864299403724
#           total_loss: 703.8772945609144
#           vf_explained_var:
#           - -0.034095097333192825
#           vf_loss: 703.8748080099782
#         model: {}
#     num_agent_steps_sampled: 40000
#     num_agent_steps_trained: 40000
#     num_steps_sampled: 40000
#     num_steps_trained: 40000
#   iterations_since_restore: 10
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.32
#     ram_util_percent: 71.53
#   pid: 105398
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07276848559847637
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10260953361965836
#     mean_inference_ms: 1.349281451327809
#     mean_raw_obs_processing_ms: 0.12042813606885197
#   time_since_restore: 70.0058581829071
#   time_this_iter_s: 6.864206552505493
#   time_total_s: 70.0058581829071
#   timers:
#     learn_throughput: 1107.371
#     learn_time_ms: 3612.16
#     load_throughput: 41517485.771
#     load_time_ms: 0.096
#     sample_throughput: 1183.859
#     sample_time_ms: 3378.781
#     update_time_ms: 1.432
#   timestamp: 1633753234
#   timesteps_since_restore: 0
#   timesteps_total: 40000
#   training_iteration: 10
#   trial_id: 10bb4_00000
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00001:
#   agent_timesteps_total: 40000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-36
#   done: true
#   episode_len_mean: 197.06
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 197.06
#   episode_reward_min: 24.0
#   episodes_this_iter: 13
#   episodes_total: 484
#   experiment_id: dcaf09a2a57b4675bbfa46bcd5916e32
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.4500000000000001
#           cur_lr: 0.009351202585093159
#           entropy: 0.5838022027925779
#           entropy_coeff: 0.0
#           kl: 0.006683794028933456
#           policy_loss: -0.009050049340873155
#           total_loss: 472.63768263375886
#           vf_explained_var:
#           - 0.022290119901299477
#           vf_loss: 472.6437239472584
#         model: {}
#     num_agent_steps_sampled: 40000
#     num_agent_steps_trained: 40000
#     num_steps_sampled: 40000
#     num_steps_trained: 40000
#   iterations_since_restore: 10
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 38.92
#     ram_util_percent: 69.69999999999999
#   pid: 105399
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07371886557862242
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10307612115638683
#     mean_inference_ms: 1.393539115870515
#     mean_raw_obs_processing_ms: 0.11989963747364446
#   time_since_restore: 71.97683548927307
#   time_this_iter_s: 6.978062868118286
#   time_total_s: 71.97683548927307
#   timers:
#     learn_throughput: 1078.714
#     learn_time_ms: 3708.118
#     load_throughput: 40117685.318
#     load_time_ms: 0.1
#     sample_throughput: 1149.677
#     sample_time_ms: 3479.238
#     update_time_ms: 1.514
#   timestamp: 1633753236
#   timesteps_since_restore: 0
#   timesteps_total: 40000
#   training_iteration: 10
#   trial_id: 10bb4_00001
#
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00002:
#   agent_timesteps_total: 4000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-50
#   done: false
#   episode_len_mean: 21.037037037037038
#   episode_media: {}
#   episode_reward_max: 66.0
#   episode_reward_mean: 21.037037037037038
#   episode_reward_min: 9.0
#   episodes_this_iter: 189
#   episodes_total: 189
#   experiment_id: 065d1d77f70f4f43a1ed5bb5d4a8d0e8
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004483018500465519
#           entropy: 0.679557925975451
#           entropy_coeff: 0.0
#           kl: 0.01478201619371952
#           policy_loss: -0.0191155838820162
#           total_loss: 88.09832624825098
#           vf_explained_var:
#           - -0.002215552143752575
#           vf_loss: 88.11448556428314
#         model: {}
#     num_agent_steps_sampled: 4000
#     num_agent_steps_trained: 4000
#     num_steps_sampled: 4000
#     num_steps_trained: 4000
#   iterations_since_restore: 1
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 41.199999999999996
#     ram_util_percent: 69.43636363636364
#   pid: 105395
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07568349278164917
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10613978823672522
#     mean_inference_ms: 1.4223688051719883
#     mean_raw_obs_processing_ms: 0.14206015280611778
#   time_since_restore: 7.3088037967681885
#   time_this_iter_s: 7.3088037967681885
#   time_total_s: 7.3088037967681885
#   timers:
#     learn_throughput: 1089.198
#     learn_time_ms: 3672.428
#     load_throughput: 50231185.629
#     load_time_ms: 0.08
#     sample_throughput: 1103.676
#     sample_time_ms: 3624.251
#     update_time_ms: 1.433
#   timestamp: 1633753250
#   timesteps_since_restore: 0
#   timesteps_total: 4000
#   training_iteration: 1
#   trial_id: 10bb4_00002
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00003:
#   agent_timesteps_total: 4000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-53
#   done: false
#   episode_len_mean: 22.23728813559322
#   episode_media: {}
#   episode_reward_max: 108.0
#   episode_reward_mean: 22.23728813559322
#   episode_reward_min: 8.0
#   episodes_this_iter: 177
#   episodes_total: 177
#   experiment_id: 75ab4d8175484643bdb5017f2b5193af
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.0037273689013248767
#           entropy: 0.6665472472226748
#           entropy_coeff: 0.0
#           kl: 0.027616884610214793
#           policy_loss: -0.0397429144290346
#           total_loss: 134.58180282346663
#           vf_explained_var:
#           - -0.05082529038190842
#           vf_loss: 134.61602292624852
#         model: {}
#     num_agent_steps_sampled: 4000
#     num_agent_steps_trained: 4000
#     num_steps_sampled: 4000
#     num_steps_trained: 4000
#   iterations_since_restore: 1
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 37.18181818181818
#     ram_util_percent: 69.92727272727274
#   pid: 105396
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.0699465754580244
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10000926824513852
#     mean_inference_ms: 1.3325156891200272
#     mean_raw_obs_processing_ms: 0.12915262404803168
#   time_since_restore: 7.18979811668396
#   time_this_iter_s: 7.18979811668396
#   time_total_s: 7.18979811668396
#   timers:
#     learn_throughput: 1051.662
#     learn_time_ms: 3803.503
#     load_throughput: 57653663.23
#     load_time_ms: 0.069
#     sample_throughput: 1186.748
#     sample_time_ms: 3370.556
#     update_time_ms: 1.341
#   timestamp: 1633753253
#   timesteps_since_restore: 0
#   timesteps_total: 4000
#   training_iteration: 1
#   trial_id: 10bb4_00003
#
# Result for PPO_CartPole-v1_10bb4_00002:
#   agent_timesteps_total: 8000
#   custom_metrics: {}
#   date: 2021-10-09_09-50-57
#   done: false
#   episode_len_mean: 29.377777777777776
#   episode_media: {}
#   episode_reward_max: 100.0
#   episode_reward_mean: 29.377777777777776
#   episode_reward_min: 9.0
#   episodes_this_iter: 135
#   episodes_total: 324
#   experiment_id: 065d1d77f70f4f43a1ed5bb5d4a8d0e8
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004483018500465519
#           entropy: 0.6514137860908303
#           entropy_coeff: 0.0
#           kl: 0.01286387854891353
#           policy_loss: -0.012907280915126365
#           total_loss: 128.24502962584137
#           vf_explained_var:
#           - 0.012635684572160244
#           vf_loss: 128.25536421909126
#         model: {}
#     num_agent_steps_sampled: 8000
#     num_agent_steps_trained: 8000
#     num_steps_sampled: 8000
#     num_steps_trained: 8000
#   iterations_since_restore: 2
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.65
#     ram_util_percent: 70.07000000000001
#   pid: 105395
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07267009017170147
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10281696842380796
#     mean_inference_ms: 1.341066226992599
#     mean_raw_obs_processing_ms: 0.13225925353073356
#   time_since_restore: 14.22378921508789
#   time_this_iter_s: 6.914985418319702
#   time_total_s: 14.22378921508789
#   timers:
#     learn_throughput: 1084.741
#     learn_time_ms: 3687.518
#     load_throughput: 43520664.073
#     load_time_ms: 0.092
#     sample_throughput: 1172.194
#     sample_time_ms: 3412.404
#     update_time_ms: 1.339
#   timestamp: 1633753257
#   timesteps_since_restore: 0
#   timesteps_total: 8000
#   training_iteration: 2
#   trial_id: 10bb4_00002
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00003:
#   agent_timesteps_total: 8000
#   custom_metrics: {}
#   date: 2021-10-09_09-51-00
#   done: false
#   episode_len_mean: 39.75
#   episode_media: {}
#   episode_reward_max: 173.0
#   episode_reward_mean: 39.75
#   episode_reward_min: 9.0
#   episodes_this_iter: 100
#   episodes_total: 277
#   experiment_id: 75ab4d8175484643bdb5017f2b5193af
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0037273689013248767
#           entropy: 0.6229057031293069
#           entropy_coeff: 0.0
#           kl: 0.018851663577147713
#           policy_loss: -0.029064248277935932
#           total_loss: 271.27264956812706
#           vf_explained_var:
#           - 0.05184866115450859
#           vf_loss: 271.29605826921363
#         model: {}
#     num_agent_steps_sampled: 8000
#     num_agent_steps_trained: 8000
#     num_steps_sampled: 8000
#     num_steps_trained: 8000
#   iterations_since_restore: 2
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.69
#     ram_util_percent: 70.11
#   pid: 105396
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07035892088989472
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.10095064057853338
#     mean_inference_ms: 1.3354616444041154
#     mean_raw_obs_processing_ms: 0.12475676609259549
#   time_since_restore: 14.421606540679932
#   time_this_iter_s: 7.231808423995972
# ...
#   episode_reward_max: 391.0
#   episode_reward_mean: 92.25
#   episode_reward_min: 9.0
#   episodes_this_iter: 25
#   episodes_total: 331
#   experiment_id: a32aa1a8880e48918b49c53738250de0
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0026816634107784377
#           entropy: 0.5901116889010194
#           entropy_coeff: 0.0
#           kl: 0.006764970864881864
#           policy_loss: -0.010886279430981445
#           total_loss: 574.7680133614489
#           vf_explained_var:
#           - 0.08385427296161652
#           vf_loss: 574.7768697759157
#         model: {}
#     num_agent_steps_sampled: 16000
#     num_agent_steps_trained: 16000
#     num_steps_sampled: 16000
#     num_steps_trained: 16000
#   iterations_since_restore: 4
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 45.333333333333336
#     ram_util_percent: 72.46666666666667
#   pid: 109351
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.08789118607875078
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.12188834647809008
#     mean_inference_ms: 1.7288178765872584
#     mean_raw_obs_processing_ms: 0.15185035303900257
#   time_since_restore: 35.998188972473145
#   time_this_iter_s: 8.714606046676636
#   time_total_s: 35.998188972473145
#   timers:
#     learn_throughput: 870.494
#     learn_time_ms: 4595.09
#     load_throughput: 40064993.433
#     load_time_ms: 0.1
#     sample_throughput: 910.726
#     sample_time_ms: 4392.1
#     update_time_ms: 1.791
#   timestamp: 1633753945
#   timesteps_since_restore: 0
#   timesteps_total: 16000
#   training_iteration: 4
#   trial_id: 10bb4_00019
#
# Result for PPO_CartPole-v1_10bb4_00018:
#   agent_timesteps_total: 24000
#   custom_metrics: {}
#   date: 2021-10-09_10-02-32
#   done: false
#   episode_len_mean: 134.15
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 134.15
#   episode_reward_min: 12.0
#   episodes_this_iter: 15
#   episodes_total: 436
#   experiment_id: 5df8f6e59d2241f1b4a2eb2118abbbf8
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004197910292460478
#           entropy: 0.5903654296551981
#           entropy_coeff: 0.0
#           kl: 0.0054351653151365874
#           policy_loss: -0.013954364465829986
#           total_loss: 592.2343485678396
#           vf_explained_var:
#           - 0.02421271614730358
#           vf_loss: 592.2472196271343
#         model: {}
#     num_agent_steps_sampled: 24000
#     num_agent_steps_trained: 24000
#     num_steps_sampled: 24000
#     num_steps_trained: 24000
#   iterations_since_restore: 6
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 46.949999999999996
#     ram_util_percent: 72.55
#   pid: 109238
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.08910591685610861
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.1253868646872659
#     mean_inference_ms: 1.7000350350822027
#     mean_raw_obs_processing_ms: 0.15168978819336573
#   time_since_restore: 52.47684121131897
#   time_this_iter_s: 8.307174921035767
#   time_total_s: 52.47684121131897
#   timers:
#     learn_throughput: 914.146
#     learn_time_ms: 4375.667
#     load_throughput: 44898883.14
#     load_time_ms: 0.089
#     sample_throughput: 917.777
#     sample_time_ms: 4358.356
#     update_time_ms: 1.806
#   timestamp: 1633753952
#   timesteps_since_restore: 0
#   timesteps_total: 24000
#   training_iteration: 6
#   trial_id: 10bb4_00018
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00019:
#   agent_timesteps_total: 20000
#   custom_metrics: {}
#   date: 2021-10-09_10-02-34
#   done: false
#   episode_len_mean: 122.94
#   episode_media: {}
#   episode_reward_max: 391.0
#   episode_reward_mean: 122.94
#   episode_reward_min: 10.0
#   episodes_this_iter: 27
#   episodes_total: 358
#   experiment_id: a32aa1a8880e48918b49c53738250de0
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0026816634107784377
#           entropy: 0.5674924215321899
#           entropy_coeff: 0.0
#           kl: 0.006690641163628633
#           policy_loss: -0.022148537543672388
#           total_loss: 365.3086512698922
#           vf_explained_var:
#           - 0.2443452626466751
#           vf_loss: 365.32879281402916
#         model: {}
#     num_agent_steps_sampled: 20000
#     num_agent_steps_trained: 20000
#     num_steps_sampled: 20000
#     num_steps_trained: 20000
#   iterations_since_restore: 5
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 46.86153846153846
#     ram_util_percent: 72.53076923076924
#   pid: 109351
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.08803727348298701
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.12187531916057838
#     mean_inference_ms: 1.7307259304933609
#     mean_raw_obs_processing_ms: 0.14869233767993476
#   time_since_restore: 44.941561460494995
#   time_this_iter_s: 8.94337248802185
#   time_total_s: 44.941561460494995
#   timers:
#     learn_throughput: 871.413
#     learn_time_ms: 4590.245
#     load_throughput: 38164731.574
#     load_time_ms: 0.105
#     sample_throughput: 911.977
#     sample_time_ms: 4386.074
#     update_time_ms: 1.742
#   timestamp: 1633753954
#   timesteps_since_restore: 0
#   timesteps_total: 20000
#   training_iteration: 5
#   trial_id: 10bb4_00019
#
# Result for PPO_CartPole-v1_10bb4_00018:
#   agent_timesteps_total: 28000
#   custom_metrics: {}
#   date: 2021-10-09_10-02-40
#   done: false
#   episode_len_mean: 163.65
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 163.65
#   episode_reward_min: 12.0
#   episodes_this_iter: 10
#   episodes_total: 446
#   experiment_id: 5df8f6e59d2241f1b4a2eb2118abbbf8
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.004197910292460478
#           entropy: 0.6054103505867784
#           entropy_coeff: 0.0
#           kl: 0.0037545048712056277
#           policy_loss: -0.004487384839724469
#           total_loss: 476.6139052278252
#           vf_explained_var:
#           - 0.09927290678024292
#           vf_loss: 476.61764127259613
#         model: {}
#     num_agent_steps_sampled: 28000
#     num_agent_steps_trained: 28000
#     num_steps_sampled: 28000
#     num_steps_trained: 28000
#   iterations_since_restore: 7
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 48.11666666666667
#     ram_util_percent: 72.61666666666666
#   pid: 109238
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.08900537758299189
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.12527751496595935
#     mean_inference_ms: 1.6969817470429822
#     mean_raw_obs_processing_ms: 0.15061283102144465
#   time_since_restore: 60.919445753097534
#   time_this_iter_s: 8.442604541778564
#   time_total_s: 60.919445753097534
#   timers:
#     learn_throughput: 909.207
#     learn_time_ms: 4399.439
#     load_throughput: 43593360.059
#     load_time_ms: 0.092
#     sample_throughput: 932.047
#     sample_time_ms: 4291.63
#     update_time_ms: 1.753
#   timestamp: 1633753960
#   timesteps_since_restore: 0
#   timesteps_total: 28000
#   training_iteration: 7
#   trial_id: 10bb4_00018
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00019:
#   agent_timesteps_total: 24000
#   custom_metrics: {}
#   date: 2021-10-09_10-02-44
#   done: false
#   episode_len_mean: 146.08
#   episode_media: {}
#   episode_reward_max: 391.0
#   episode_reward_mean: 146.08
#   episode_reward_min: 10.0
#   episodes_this_iter: 16
#   episodes_total: 374
#   experiment_id: a32aa1a8880e48918b49c53738250de0
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0026816634107784377
#           entropy: 0.5667663622927922
#           entropy_coeff: 0.0
#           kl: 0.00577908945935175
#           policy_loss: -0.009177427041915156
#           total_loss: 506.23637034098306
#           vf_explained_var:
#           - 0.06279611587524414
#           vf_loss: 506.24381717148646
#         model: {}
#     num_agent_steps_sampled: 24000
#     num_agent_steps_trained: 24000
#     num_steps_sampled: 24000
#     num_steps_trained: 24000
#   iterations_since_restore: 6
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 47.67692307692308
#     ram_util_percent: 72.60769230769232
#   pid: 109351
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.08825779709709047
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.12228147191957746
#     mean_inference_ms: 1.7330748056094563
#     mean_raw_obs_processing_ms: 0.14767322857524706
#   time_since_restore: 54.135868549346924
#   time_this_iter_s: 9.194307088851929
#   time_total_s: 54.135868549346924
#   timers:
#     learn_throughput: 868.74
#     learn_time_ms: 4604.369
#     load_throughput: 40072968.153
#     load_time_ms: 0.1
#     sample_throughput: 907.768
#     sample_time_ms: 4406.413
#     update_time_ms: 1.756
#   timestamp: 1633753964
#   timesteps_since_restore: 0
#   timesteps_total: 24000
#   training_iteration: 6
#   trial_id: 10bb4_00019
#
# Result for PPO_CartPole-v1_10bb4_00018:
#   agent_timesteps_total: 32000
#   custom_metrics: {}
#   date: 2021-10-09_10-02-49
#   done: true
#   episode_len_mean: 198.09
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 198.09
#   episode_reward_min: 15.0
#   episodes_this_iter: 10
#   episodes_total: 456
#   experiment_id: 5df8f6e59d2241f1b4a2eb2118abbbf8
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.10000000000000002
#           cur_lr: 0.004197910292460478
#           entropy: 0.5922942629424475
#           entropy_coeff: 0.0
#           kl: 0.007739378170498164
#           policy_loss: -0.006896065239624311
#           total_loss: 507.7451060797579
#           vf_explained_var:
#           - -0.06297796219587326
#           vf_loss: 507.75122518641973
#         model: {}
#     num_agent_steps_sampled: 32000
#     num_agent_steps_trained: 32000
#     num_steps_sampled: 32000
#     num_steps_trained: 32000
#   iterations_since_restore: 8
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 44.48333333333333
#     ram_util_percent: 72.50833333333333
#   pid: 109238
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.0888160613417751
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.12506947735455984
#     mean_inference_ms: 1.6917057197525858
#     mean_raw_obs_processing_ms: 0.14928143088620174
#   time_since_restore: 69.2124490737915
#   time_this_iter_s: 8.29300332069397
#   time_total_s: 69.2124490737915
#   timers:
#     learn_throughput: 905.941
#     learn_time_ms: 4415.297
#     load_throughput: 43394027.805
#     load_time_ms: 0.092
#     sample_throughput: 946.777
#     sample_time_ms: 4224.86
#     update_time_ms: 1.724
#   timestamp: 1633753969
#   timesteps_since_restore: 0
#   timesteps_total: 32000
#   training_iteration: 8
#   trial_id: 10bb4_00018
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_10bb4_00019:
#   agent_timesteps_total: 28000
#   custom_metrics: {}
#   date: 2021-10-09_10-02-51
#   done: false
#   episode_len_mean: 176.17
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 176.17
#   episode_reward_min: 10.0
#   episodes_this_iter: 13
#   episodes_total: 387
#   experiment_id: a32aa1a8880e48918b49c53738250de0
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0026816634107784377
#           entropy: 0.5640793178350695
#           entropy_coeff: 0.0
#           kl: 0.004991771217633768
#           policy_loss: -0.007619361623480756
#           total_loss: 445.9278995308825
#           vf_explained_var:
#           - 0.02513176202774048
#           vf_loss: 445.9340199542302
#         model: {}
#     num_agent_steps_sampled: 28000
#     num_agent_steps_trained: 28000
#     num_steps_sampled: 28000
#     num_steps_trained: 28000
#   iterations_since_restore: 7
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 39.85454545454545
#     ram_util_percent: 69.85454545454546
#   pid: 109351
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.08828058305806417
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.12245555472564712
#     mean_inference_ms: 1.7312014479916984
#     mean_raw_obs_processing_ms: 0.14670898837292537
#   time_since_restore: 61.85154438018799
#   time_this_iter_s: 7.7156758308410645
#   time_total_s: 61.85154438018799
#   timers:
#     learn_throughput: 892.699
#     learn_time_ms: 4480.795
#     load_throughput: 41868275.223
#     load_time_ms: 0.096
#     sample_throughput: 920.843
#     sample_time_ms: 4343.844
#     update_time_ms: 1.669
#   timestamp: 1633753971
#   timesteps_since_restore: 0
#   timesteps_total: 28000
#   training_iteration: 7
#   trial_id: 10bb4_00019
#
# Result for PPO_CartPole-v1_10bb4_00019:
#   agent_timesteps_total: 32000
#   custom_metrics: {}
#   date: 2021-10-09_10-02-58
#   done: true
#   episode_len_mean: 207.25
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 207.25
#   episode_reward_min: 10.0
#   episodes_this_iter: 13
#   episodes_total: 400
#   experiment_id: a32aa1a8880e48918b49c53738250de0
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.15
#           cur_lr: 0.0026816634107784377
#           entropy: 0.56488225492098
#           entropy_coeff: 0.0
#           kl: 0.007617294341348173
#           policy_loss: -0.01402793425205414
#           total_loss: 547.0757311913275
#           vf_explained_var:
#           - 0.037610068917274475
#           vf_loss: 547.0886147940031
#         model: {}
#     num_agent_steps_sampled: 32000
#     num_agent_steps_trained: 32000
#     num_steps_sampled: 32000
#     num_steps_trained: 32000
#   iterations_since_restore: 8
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 27.0
#     ram_util_percent: 60.379999999999995
#   pid: 109351
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.08779538525205657
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.121797370701964
#     mean_inference_ms: 1.7202271267001847
#     mean_raw_obs_processing_ms: 0.14443838644404094
#   time_since_restore: 68.76776885986328
#   time_this_iter_s: 6.916224479675293
#   time_total_s: 68.76776885986328
#   timers:
#     learn_throughput: 912.089
#     learn_time_ms: 4385.538
#     load_throughput: 42061337.512
#     load_time_ms: 0.095
#     sample_throughput: 952.479
#     sample_time_ms: 4199.567
#     update_time_ms: 1.602
#   timestamp: 1633753978
#   timesteps_since_restore: 0
#   timesteps_total: 32000
#   training_iteration: 8
#   trial_id: 10bb4_00019
#
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# 2021-10-09 10:02:59,172	INFO tune.py:561 -- Total run time: 823.19 seconds (822.67 seconds for the tuning loop).

# %%
# Views the best values for hyperparameters
print("Best hyperparameters:", parameters_search_analysis.best_config)
# Out:
# Best hyperparameters: {'env': 'CartPole-v1', 'framework': 'torch', 'model': {'fcnet_hiddens': [64], 'fcnet_activation': 'relu'}, 'lr': 0.003727368901324877}

# %% [markdown]
# ## Retraining the Agent with Tuned Hyperparameters

# %%
ray.shutdown()

ray.init(
    num_cpus=8,
    include_dashboard=False,
    ignore_reinit_error=True,
    log_to_driver=False,
)
# Out:
# {'node_ip_address': '192.168.226.49',
#  'raylet_ip_address': '192.168.226.49',
#  'redis_address': '192.168.226.49:6379',
#  'object_store_address': '/tmp/ray/session_2021-10-09_10-21-58_359382_72352/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-10-09_10-21-58_359382_72352/sockets/raylet',
#  'webui_url': None,
#  'session_dir': '/tmp/ray/session_2021-10-09_10-21-58_359382_72352',
#  'metrics_export_port': 62678,
#  'node_id': '4ad1174836f3ea4edfa6c206dfbda2f26ebea279b39be86307ed22bf'}

# %%
# Performs training with the best values of hyperparameters

training_with_tuned_parameters_analysis = ray.tune.run(
    "PPO",
    config=parameters_search_analysis.best_config,
    stop=stop,
    checkpoint_at_end=True,
)
# Out:
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_60411_00000:
#   agent_timesteps_total: 4000
#   custom_metrics: {}
#   date: 2021-10-09_10-41-48
#   done: false
#   episode_len_mean: 21.04232804232804
#   episode_media: {}
#   episode_reward_max: 73.0
#   episode_reward_mean: 21.04232804232804
#   episode_reward_min: 9.0
#   episodes_this_iter: 189
#   episodes_total: 189
#   experiment_id: 7f23a769fb404aa7a6cfa49df42b3c7e
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.20000000000000004
#           cur_lr: 0.0037273689013248767
#           entropy: 0.6663280891474858
#           entropy_coeff: 0.0
#           kl: 0.028486253287748342
#           policy_loss: -0.04149572960932248
#           total_loss: 76.68353492982926
#           vf_explained_var:
#           - -0.055846989154815674
#           vf_loss: 76.71933348871046
#         model: {}
#     num_agent_steps_sampled: 4000
#     num_agent_steps_trained: 4000
#     num_steps_sampled: 4000
#     num_steps_trained: 4000
#   iterations_since_restore: 1
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 20.5
#     ram_util_percent: 67.63333333333334
#   pid: 110040
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05936659877555563
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08544733845402626
#     mean_inference_ms: 1.099208125951764
#     mean_raw_obs_processing_ms: 0.11175100850953176
#   time_since_restore: 6.007507562637329
#   time_this_iter_s: 6.007507562637329
#   time_total_s: 6.007507562637329
#   timers:
#     learn_throughput: 1251.249
#     learn_time_ms: 3196.807
#     load_throughput: 31536120.301
#     load_time_ms: 0.127
#     sample_throughput: 1429.644
#     sample_time_ms: 2797.9
#     update_time_ms: 1.194
#   timestamp: 1633756308
#   timesteps_since_restore: 0
#   timesteps_total: 4000
#   training_iteration: 1
#   trial_id: '60411_00000'
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_60411_00000:
#   agent_timesteps_total: 8000
#   custom_metrics: {}
#   date: 2021-10-09_10-41-54
#   done: false
#   episode_len_mean: 39.84
#   episode_media: {}
#   episode_reward_max: 115.0
#   episode_reward_mean: 39.84
#   episode_reward_min: 10.0
#   episodes_this_iter: 99
#   episodes_total: 288
#   experiment_id: 7f23a769fb404aa7a6cfa49df42b3c7e
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0037273689013248767
#           entropy: 0.6266125211792607
#           entropy_coeff: 0.0
#           kl: 0.01877416944223063
#           policy_loss: -0.03438183525276761
#           total_loss: 193.33251551146148
#           vf_explained_var:
#           - 0.008732213638722897
#           vf_loss: 193.36126520300425
#         model: {}
#     num_agent_steps_sampled: 8000
#     num_agent_steps_trained: 8000
#     num_steps_sampled: 8000
#     num_steps_trained: 8000
#   iterations_since_restore: 2
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 23.9
#     ram_util_percent: 67.75555555555555
#   pid: 110040
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05906907128973117
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08531406882929739
#     mean_inference_ms: 1.0881221738105475
#     mean_raw_obs_processing_ms: 0.1066699131808505
#   time_since_restore: 12.030369520187378
#   time_this_iter_s: 6.022861957550049
#   time_total_s: 12.030369520187378
#   timers:
#     learn_throughput: 1232.523
#     learn_time_ms: 3245.376
#     load_throughput: 33554432.0
#     load_time_ms: 0.119
#     sample_throughput: 1450.168
#     sample_time_ms: 2758.3
#     update_time_ms: 1.168
#   timestamp: 1633756314
#   timesteps_since_restore: 0
#   timesteps_total: 8000
#   training_iteration: 2
#   trial_id: '60411_00000'
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_60411_00000:
#   agent_timesteps_total: 12000
#   custom_metrics: {}
#   date: 2021-10-09_10-42-00
#   done: false
#   episode_len_mean: 61.56
#   episode_media: {}
#   episode_reward_max: 226.0
#   episode_reward_mean: 61.56
#   episode_reward_min: 10.0
#   episodes_this_iter: 50
#   episodes_total: 338
#   experiment_id: 7f23a769fb404aa7a6cfa49df42b3c7e
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0037273689013248767
#           entropy: 0.5914454597939727
#           entropy_coeff: 0.0
#           kl: 0.012739757653359877
#           policy_loss: -0.01989383355423968
#           total_loss: 319.854302149947
#           vf_explained_var:
#           - 0.005082458723336458
#           vf_loss: 319.8703730429373
#         model: {}
#     num_agent_steps_sampled: 12000
#     num_agent_steps_trained: 12000
#     num_steps_sampled: 12000
#     num_steps_trained: 12000
#   iterations_since_restore: 3
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 29.877777777777776
#     ram_util_percent: 67.65555555555555
#   pid: 110040
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05993328353894533
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08600959697607408
#     mean_inference_ms: 1.0972789313679843
#     mean_raw_obs_processing_ms: 0.10582010228937065
#   time_since_restore: 18.461389303207397
#   time_this_iter_s: 6.4310197830200195
#   time_total_s: 18.461389303207397
#   timers:
#     learn_throughput: 1193.412
#     learn_time_ms: 3351.735
#     load_throughput: 34123151.186
#     load_time_ms: 0.117
#     sample_throughput: 1432.981
#     sample_time_ms: 2791.385
#     update_time_ms: 1.188
#   timestamp: 1633756320
#   timesteps_since_restore: 0
#   timesteps_total: 12000
#   training_iteration: 3
#   trial_id: '60411_00000'
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_60411_00000:
#   agent_timesteps_total: 16000
#   custom_metrics: {}
#   date: 2021-10-09_10-42-07
#   done: false
#   episode_len_mean: 88.15
#   episode_media: {}
#   episode_reward_max: 274.0
#   episode_reward_mean: 88.15
#   episode_reward_min: 10.0
#   episodes_this_iter: 31
#   episodes_total: 369
#   experiment_id: 7f23a769fb404aa7a6cfa49df42b3c7e
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0037273689013248767
#           entropy: 0.586584904501515
#           entropy_coeff: 0.0
#           kl: 0.009385340056420546
#           policy_loss: -0.015432116397285974
#           total_loss: 560.6607371176443
#           vf_explained_var:
#           - 0.14826683700084686
#           vf_loss: 560.6733517390426
#         model: {}
#     num_agent_steps_sampled: 16000
#     num_agent_steps_trained: 16000
#     num_steps_sampled: 16000
#     num_steps_trained: 16000
#   iterations_since_restore: 4
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 25.38888888888889
#     ram_util_percent: 67.5111111111111
#   pid: 110040
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06013458213785674
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08659308653135665
#     mean_inference_ms: 1.1019880237178419
#     mean_raw_obs_processing_ms: 0.10449155407860992
#   time_since_restore: 24.636199712753296
#   time_this_iter_s: 6.174810409545898
#   time_total_s: 24.636199712753296
#   timers:
#     learn_throughput: 1189.165
#     learn_time_ms: 3363.706
#     load_throughput: 36275061.622
#     load_time_ms: 0.11
#     sample_throughput: 1436.202
#     sample_time_ms: 2785.123
#     update_time_ms: 1.184
#   timestamp: 1633756327
#   timesteps_since_restore: 0
#   timesteps_total: 16000
#   training_iteration: 4
#   trial_id: '60411_00000'
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_60411_00000:
#   agent_timesteps_total: 20000
#   custom_metrics: {}
#   date: 2021-10-09_10-42-13
#   done: false
#   episode_len_mean: 114.06
#   episode_media: {}
#   episode_reward_max: 383.0
#   episode_reward_mean: 114.06
#   episode_reward_min: 10.0
#   episodes_this_iter: 26
#   episodes_total: 395
#   experiment_id: 7f23a769fb404aa7a6cfa49df42b3c7e
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0037273689013248767
#           entropy: 0.568190707186217
#           entropy_coeff: 0.0
#           kl: 0.008539230768016541
#           policy_loss: -0.014314690904231162
#           total_loss: 404.7528193402034
#           vf_explained_var:
#           - 0.19525858759880066
#           vf_loss: 404.7645721271474
#         model: {}
#     num_agent_steps_sampled: 20000
#     num_agent_steps_trained: 20000
#     num_steps_sampled: 20000
#     num_steps_trained: 20000
#   iterations_since_restore: 5
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 25.1125
#     ram_util_percent: 67.51249999999999
#   pid: 110040
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06036939776301427
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08710597605782945
#     mean_inference_ms: 1.1067505735369232
#     mean_raw_obs_processing_ms: 0.10330720651432895
#   time_since_restore: 30.641981840133667
#   time_this_iter_s: 6.005782127380371
#   time_total_s: 30.641981840133667
#   timers:
#     learn_throughput: 1205.232
#     learn_time_ms: 3318.862
#     load_throughput: 39662449.173
#     load_time_ms: 0.101
#     sample_throughput: 1428.638
#     sample_time_ms: 2799.87
#     update_time_ms: 1.167
#   timestamp: 1633756333
#   timesteps_since_restore: 0
#   timesteps_total: 20000
#   training_iteration: 5
#   trial_id: '60411_00000'
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_60411_00000:
#   agent_timesteps_total: 24000
#   custom_metrics: {}
#   date: 2021-10-09_10-42-19
#   done: false
#   episode_len_mean: 138.74
#   episode_media: {}
#   episode_reward_max: 416.0
#   episode_reward_mean: 138.74
#   episode_reward_min: 10.0
#   episodes_this_iter: 15
#   episodes_total: 410
#   experiment_id: 7f23a769fb404aa7a6cfa49df42b3c7e
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0037273689013248767
#           entropy: 0.5704406854926899
#           entropy_coeff: 0.0
#           kl: 0.008356839848756853
#           policy_loss: -0.015889978993643996
#           total_loss: 352.6532937490812
#           vf_explained_var:
#           - 0.45448535680770874
#           vf_loss: 352.666676035235
#         model: {}
#     num_agent_steps_sampled: 24000
#     num_agent_steps_trained: 24000
#     num_steps_sampled: 24000
#     num_steps_trained: 24000
#   iterations_since_restore: 6
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 22.422222222222224
#     ram_util_percent: 67.47777777777777
#   pid: 110040
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06052851140206141
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08714616272315188
#     mean_inference_ms: 1.1080721164941645
#     mean_raw_obs_processing_ms: 0.10272804448800986
#   time_since_restore: 36.58947801589966
#   time_this_iter_s: 5.947496175765991
#   time_total_s: 36.58947801589966
#   timers:
#     learn_throughput: 1216.161
#     learn_time_ms: 3289.04
#     load_throughput: 40217057.93
#     load_time_ms: 0.099
#     sample_throughput: 1428.695
#     sample_time_ms: 2799.757
#     update_time_ms: 1.159
#   timestamp: 1633756339
#   timesteps_since_restore: 0
#   timesteps_total: 24000
#   training_iteration: 6
#   trial_id: '60411_00000'
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_60411_00000:
#   agent_timesteps_total: 28000
#   custom_metrics: {}
#   date: 2021-10-09_10-42-25
#   done: false
#   episode_len_mean: 169.07
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 169.07
#   episode_reward_min: 13.0
#   episodes_this_iter: 11
#   episodes_total: 421
#   experiment_id: 7f23a769fb404aa7a6cfa49df42b3c7e
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0037273689013248767
#           entropy: 0.5641057321781753
#           entropy_coeff: 0.0
#           kl: 0.008143625626402624
#           policy_loss: -0.013139410619874314
#           total_loss: 313.56337434091876
#           vf_explained_var:
#           - 0.29184839129447937
#           vf_loss: 313.574071117114
#         model: {}
#     num_agent_steps_sampled: 28000
#     num_agent_steps_trained: 28000
#     num_steps_sampled: 28000
#     num_steps_trained: 28000
#   iterations_since_restore: 7
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 21.65
#     ram_util_percent: 67.5
#   pid: 110040
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.06050026051252416
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08717250772200207
#     mean_inference_ms: 1.1076997247035578
#     mean_raw_obs_processing_ms: 0.10210565901549085
#   time_since_restore: 42.35256576538086
#   time_this_iter_s: 5.763087749481201
#   time_total_s: 42.35256576538086
#   timers:
#     learn_throughput: 1228.493
#     learn_time_ms: 3256.021
#     load_throughput: 40806293.259
#     load_time_ms: 0.098
#     sample_throughput: 1436.243
#     sample_time_ms: 2785.044
#     update_time_ms: 1.158
#   timestamp: 1633756345
#   timesteps_since_restore: 0
#   timesteps_total: 28000
#   training_iteration: 7
#   trial_id: '60411_00000'
#
# <IPython.core.display.HTML object>
# Result for PPO_CartPole-v1_60411_00000:
#   agent_timesteps_total: 32000
#   custom_metrics: {}
#   date: 2021-10-09_10-42-30
#   done: true
#   episode_len_mean: 203.51
#   episode_media: {}
#   episode_reward_max: 500.0
#   episode_reward_mean: 203.51
#   episode_reward_min: 13.0
#   episodes_this_iter: 8
#   episodes_total: 429
#   experiment_id: 7f23a769fb404aa7a6cfa49df42b3c7e
#   hostname: avita-pura-ns14a6
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.3
#           cur_lr: 0.0037273689013248767
#           entropy: 0.5661725400596537
#           entropy_coeff: 0.0
#           kl: 0.00816637931764622
#           policy_loss: -0.009979954201187337
#           total_loss: 448.9006897054693
#           vf_explained_var:
#           - -0.21714533865451813
#           vf_loss: 448.90821780440626
#         model: {}
#     num_agent_steps_sampled: 32000
#     num_agent_steps_trained: 32000
#     num_steps_sampled: 32000
#     num_steps_trained: 32000
#   iterations_since_restore: 8
#   node_ip: 192.168.226.49
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 20.688888888888886
#     ram_util_percent: 67.46666666666665
#   pid: 110040
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.060426162282673425
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.08718801709061239
#     mean_inference_ms: 1.1068637775009977
#     mean_raw_obs_processing_ms: 0.10155392505734832
#   time_since_restore: 48.188358545303345
#   time_this_iter_s: 5.835792779922485
#   time_total_s: 48.188358545303345
#   timers:
#     learn_throughput: 1234.252
#     learn_time_ms: 3240.83
#     load_throughput: 42676543.084
#     load_time_ms: 0.094
#     sample_throughput: 1442.142
#     sample_time_ms: 2773.653
#     update_time_ms: 1.149
#   timestamp: 1633756350
#   timesteps_since_restore: 0
#   timesteps_total: 32000
#   training_iteration: 8
#   trial_id: '60411_00000'
#
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# 2021-10-09 10:42:31,605	INFO tune.py:561 -- Total run time: 55.57 seconds (54.89 seconds for the tuning loop).

# %%
trial = training_with_tuned_parameters_analysis.get_best_logdir("episode_reward_mean", "max")
checkpoint = training_with_tuned_parameters_analysis.get_best_checkpoint(trial, "training_iteration", "max")
trainer = PPOTrainer(config=parameters_search_analysis.best_config)
trainer.restore(checkpoint)
# Out:
# 2021-10-09 10:44:45,478	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# 2021-10-09 10:44:45,489	INFO trainable.py:383 -- Restored on 192.168.226.49 from checkpoint: /home/pradip/ray_results/PPO/PPO_CartPole-v1_60411_00000_0_2021-10-09_10-41-36/checkpoint_000008/checkpoint-8
# 2021-10-09 10:44:45,491	INFO trainable.py:390 -- Current state after restoring: {'_iteration': 8, '_timesteps_total': None, '_time_total': 48.188358545303345, '_episodes_total': 429}

# %% [markdown]
# **Creating video**

# %%
after_training_with_tuned_hyperparameters_video_file = "after_training_with_tuned_hyperparameters.mp4"
after_training_with_tuned_hyperparameters_video = VideoRecorder(env, after_training_with_tuned_hyperparameters_video_file)
observation = env.reset()
done = False
while not done:
    env.render()
    after_training_with_tuned_hyperparameters_video.capture_frame()
    action = trainer.compute_single_action(observation)
    observation, reward, done, info = env.step(action)
after_training_with_tuned_hyperparameters_video.close()
env.close()

# %%
# Displays the recorded video here in notebook
from IPython.display import HTML
from render_video import render_mp4
html = render_mp4(after_training_with_tuned_hyperparameters_video_file)
HTML(html)
# Out:
# <video width=400 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>
